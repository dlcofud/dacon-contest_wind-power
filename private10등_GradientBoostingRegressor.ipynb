# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

# %%
import pandas as pd

train = pd.read_csv('/content/drive/MyDrive/연암공대풍력/train.csv')
train.head()
# Out:
#    ID     온도  최저_온도  최고_온도      기압  습도    풍속   풍향  강수량  강설량  구름_밀집도 날씨_주요_요소  \
# 0   0   9.90   9.90    9.9  102502  66  14.4  113  0.0  0.0      92       흐림
# 1   1  10.30  10.30   10.3  101808  90   7.2   95  0.0  0.0      92       흐림
# 2   2  15.00  15.00   15.0  101908  62  10.8  270  0.0  0.0      40       흐림
# 3   3  25.00  25.00   25.0  101503  69  28.8   50  0.0  0.0      20       흐림
# 4   4  19.43  18.89   20.0  101602  56  14.4  150  0.0  0.0      20       흐림
#
#   날씨_상세_설명  풍력_발전량
# 0       흐림  2627.0
# 1       흐림  8593.0
# 2    산개 구름  4643.0
# 3    구름 조금  6219.0
# 4    구름 조금  7426.0

# %%
test = pd.read_csv('/content/drive/MyDrive/연암공대풍력/test.csv')
test.head()
# Out:
#    ID    온도  최저_온도  최고_온도      기압  습도    풍속   풍향  강수량  강설량  구름_밀집도 날씨_주요_요소  \
# 0   0   8.0    8.0    8.0  102505  78  10.8  290  0.0  0.0       0       맑음
# 1   1  14.0   14.0   14.0  101809  46  28.8  320  0.0  0.0       0       맑음
# 2   2  28.0   28.0   28.0  101501  65  18.0   50  0.0  0.0      20       흐림
# 3   3  29.0   29.0   29.0  101905  58  10.8  110  0.0  0.0       0       맑음
# 4   4  20.0   20.0   20.0  102106  60   0.0    0  0.0  0.0       0       맑음
#
#   날씨_상세_설명
# 0       맑음
# 1       맑음
# 2    구름 조금
# 3       맑음
# 4       맑음

# %%
sample_submission = pd.read_csv('/content/drive/MyDrive/연암공대풍력/sample_submission.csv')
sample_submission.head()
# Out:
#    ID    온도  최저_온도  최고_온도      기압  습도    풍속   풍향  강수량  강설량  구름_밀집도
# 0   0   8.0    8.0    8.0  102505  78  10.8  290  0.0  0.0       0
# 1   1  14.0   14.0   14.0  101809  46  28.8  320  0.0  0.0       0
# 2   2  28.0   28.0   28.0  101501  65  18.0   50  0.0  0.0      20
# 3   3  29.0   29.0   29.0  101905  58  10.8  110  0.0  0.0       0
# 4   4  20.0   20.0   20.0  102106  60   0.0    0  0.0  0.0       0

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# 데이터 불러오기
train_data = pd.read_csv('/content/drive/MyDrive/연암공대풍력/train.csv')
test_data = pd.read_csv('/content/drive/MyDrive/연암공대풍력/test.csv')

# 필요없는 열 제거하기
train_data = train_data.drop(['날씨_주요_요소', '날씨_상세_설명', '강수량','강설량','구름_밀집도','습도'], axis=1)
test_data = test_data.drop(['날씨_주요_요소', '날씨_상세_설명', '강수량','강설량','구름_밀집도','습도'], axis=1)

# 필요한 열 선택
X_train = train_data.drop(columns=['풍력_발전량'], axis=1)  # 학습 데이터의 특성
y_train = train_data['풍력_발전량']  # 학습 데이터의 타겟 변수

X_test = test_data  # 테스트 데이터의 특성 (테스트 데이터에는 타겟 열이 없음)

# 데이터 전처리 (표준화)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 딥러닝 모델 정의
#model = keras.Sequential([
    #keras.layers.Dense(64, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    #keras.layers.Dropout(0.5),  # Dropout 추가
    #keras.layers.Dense(128, activation='relu'),
    #keras.layers.Dropout(0.5),  # Dropout 추가
    #keras.layers.Dense(1)
#])

model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)

# Model training
model.fit(X_train_scaled, y_train)

# 테스트 데이터에 대한 예측 수행
y_pred = model.predict(X_test_scaled)

# %%
# 예측 결과를 sample_submission.csv 파일에 추가
sample_submission = pd.read_csv('/content/drive/MyDrive/연암공대풍력/sample_submission.csv')
sample_submission['풍력_발전량'] = y_pred

# %%
sample_submission
# Out:
#           ID    온도  최저_온도  최고_온도      기압  습도    풍속   풍향  강수량  강설량  구름_밀집도  \
# 0          0   8.0    8.0    8.0  102505  78  10.8  290  0.0  0.0       0
# 1          1  14.0   14.0   14.0  101809  46  28.8  320  0.0  0.0       0
# 2          2  28.0   28.0   28.0  101501  65  18.0   50  0.0  0.0      20
# 3          3  29.0   29.0   29.0  101905  58  10.8  110  0.0  0.0       0
# 4          4  20.0   20.0   20.0  102106  60   0.0    0  0.0  0.0       0
# ...      ...   ...    ...    ...     ...  ..   ...  ...  ...  ...     ...
# 10533  10533  28.0   28.0   28.0  101400  34  14.4  120  0.0  0.0       0
# 10534  10534  21.0   21.0   21.0  101703  68  10.8   50  0.0  0.0      20
# 10535  10535  17.0   17.0   17.0  101808  82   3.6  320  0.0  0.0      20
# 10536  10536  20.0   20.0   20.0  102005  28   7.2  220  0.0  0.0       0
# 10537  10537  27.0   27.0   27.0  102004  47   7.2  130  0.0  0.0      75
#
#             풍력_발전량
# 0      5841.701211
# 1      8187.047251
# ...

# %%
sample_submission = sample_submission.drop(['온도','최저_온도','최고_온도','기압','풍속','풍향', '강수량','강설량','구름_밀집도','습도'], axis=1)

# %%
sample_submission.to_csv('Submission16.csv', index=False)
